# %% [markdown]
# <a href="https://colab.research.google.com/github/0mehedihasan/AI-Beginner-to-Advance/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data/california_housing_test.csv')

# Print the first 5 rows of the data
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
col_room=data['total_rooms']
col_room
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
col_room_bedroom = data[['total_rooms', 'total_bedrooms']]
col_room_bedroom
# Out:
#       total_rooms  total_bedrooms
# 0          3885.0           661.0
# 1          1510.0           310.0
# 2          3589.0           507.0
# 3            67.0            15.0
# 4          1241.0           244.0
# ...           ...             ...
# 2995       1450.0           642.0
# 2996       5257.0          1082.0
# 2997        956.0           201.0
# 2998         96.0            14.0
# 2999       1765.0           263.0
#
# [3000 rows x 2 columns]

# %%
filtered_data = data[data['population'] > 1000]
filtered_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# ...         ...       ...                 ...          ...             ...
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
filtered_data1 = data[(data['population'] > 1000) & (data['households'] > 500)]
filtered_data1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
filtered_data2 = data[(data['population'] > 1000) | (data['households'] > 500)]
filtered_data2
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# ...         ...       ...                 ...          ...             ...
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
ascending_population = data.sort_values('population')
ascending_population
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2640    -114.62     33.62                26.0         18.0             3.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# 2494    -118.44     34.04                49.0         32.0             7.0
# ...         ...       ...                 ...          ...             ...
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 2186    -116.14     34.45                12.0       8796.0          1721.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
#
#       population  households  median_income  median_house_value
# ...

# %%
ascending_population = data.sort_values(by=['population', 'households'])
ascending_population
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2640    -114.62     33.62                26.0         18.0             3.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 2494    -118.44     34.04                49.0         32.0             7.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# ...         ...       ...                 ...          ...             ...
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 2186    -116.14     34.45                12.0       8796.0          1721.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
#
#       population  households  median_income  median_house_value
# ...

# %%
descending_population = data.sort_values('population', ascending=False)
descending_population
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 978     -121.53     38.48                 5.0      27870.0          5027.0
# 2186    -116.14     34.45                12.0       8796.0          1721.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# ...         ...       ...                 ...          ...             ...
# 2494    -118.44     34.04                49.0         32.0             7.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 2640    -114.62     33.62                26.0         18.0             3.0
#
#       population  households  median_income  median_house_value
# ...

# %%
data['new_column']=data['total_rooms']+data['total_bedrooms']
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df={
    'mehedi':[1,2,3],
    'hasan':[4,5,6],
    'a':[None,8,9]
    }
df=pd.DataFrame(df)
df
# Out:
#    mehedi  hasan    a
# 0       1      4  NaN
# 1       2      5  8.0
# 2       3      6  9.0

# %%
df['newcol'] = df['mehedi'].apply(lambda x: x + 2 if x > 1 else x)
df
# Out:
#    mehedi  hasan    a  newcol
# 0       1      4  NaN       1
# 1       2      5  8.0       4
# 2       3      6  9.0       5

# %%
df.isnull().sum()
# Out:
# mehedi    0
# hasan     0
# a         1
# newcol    0
# dtype: int64

# %%
avg_a = df['a'].mean()
df['a'] = df['a'].fillna(avg_a)
df
# Out:
#    mehedi  hasan    a  newcol
# 0       1      4  8.5       1
# 1       2      5  8.0       4
# 2       3      6  9.0       5

# %%
avg_a = df['a'].max()
df['a'] = df['a'].fillna(avg_a)
df
# Out:
#    mehedi  hasan    a  newcol
# 0       1      4  8.5       1
# 1       2      5  8.0       4
# 2       3      6  9.0       5
